# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = 'C:/Users/kalya/OneDrive/Desktop/TYITB090/Iris.csv'
df = pd.read_csv(data)

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.describe(include=['object'])
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df['SepalLengthCm'].mean()
# Out:
# 5.843333333333334

# %%
mean = df['SepalLengthCm'].mean()

print(mean)
# Out:
# 5.843333333333334

# %%
median = df['SepalWidthCm'].median()
print(median)
# Out:
# 3.0

# %%
mode = df['PetalLengthCm'].mode()
print(mode)
# Out:
# 0    1.5
# Name: PetalLengthCm, dtype: float64

# %%
df['SepalWidthCm'].min()
# Out:
# 2.0

# %%
df['SepalWidthCm'].max()
# Out:
# 4.4

# %%
df['SepalWidthCm'].max() - df['SepalWidthCm'].min()
# Out:
# 2.4000000000000004

# %%
df['SepalWidthCm'].var()
# Out:
# 0.1880040268456376

# %%
df['SepalWidthCm'].std()
# Out:
# 0.4335943113621737

# %%
q2=df['SepalLengthCm'].quantile(0.5)
q2
# Out:
# 5.8

# %%
q3=df['SepalLengthCm'].quantile(0.75)
print(q3)
# Out:
# 6.4

# %%
df['SepalLengthCm'].skew()
# Out:
# 0.3149109566369728

# %%
df['SepalLengthCm'].kurt()
# Out:
# -0.5520640413156395

# %%
data = df['SepalLengthCm']
sns.distplot(data, bins=10, hist=True, kde=True, label='SepalLengthCm',color="black")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
plt.boxplot(df['SepalLengthCm'])
plt.show()

# %%
data = df['SepalWidthCm']
sns.distplot(data, bins=10, hist=True, kde=True, label = 'SepalWidthCm')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
plt.boxplot(df['SepalWidthCm'])
plt.show()

# %%
data = df['PetalLengthCm']
sns.distplot(data, bins=10, hist=True, kde=True, label = 'PetalLengthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
plt.boxplot(df['PetalLengthCm'])
plt.show()

# %%
data = df['PetalWidthCm']
sns.distplot(data, bins=10, hist=True, kde=True, label = 'PetalWidthCm')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
plt.boxplot(df['PetalWidthCm'])
plt.show()

# %%
data = df['SepalWidthCm']
sns.distplot(data, bins=10, hist=True, kde=True, label = 'SepalWidthCm',color="purple")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>
